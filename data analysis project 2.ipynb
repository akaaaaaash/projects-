# %%
import numpy as np
import pandas as pd
import glob
import os

# %%
os.chdir("C:\\Users\\91955\\Pandas-Data-Science-Tasks-master\\SalesAnalysis")

# %%
m=pd.read_csv("all_months.csv")

# %%
dfk=pd.DataFrame(m)

# %%
dfk
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1 Order ID  \
# 0                0             0               0                 0   176558
# 1                1             1               1                 1      NaN
# 2                2             2               2                 2   176559
# 3                3             3               3                 3   176560
# 4                4             4               4                 4   176560
# ...            ...           ...             ...               ...      ...
# 186845      186845        186845          186845             11681   259353
# 186846      186846        186846          186846             11682   259354
# 186847      186847        186847          186847             11683   259355
# 186848      186848        186848          186848             11684   259356
# 186849      186849        186849          186849             11685   259357
#
# ...

# %%
dfk=dfk.dropna(how='any')

# %%
dfk
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1 Order ID  \
# 0                0             0               0                 0   176558
# 2                2             2               2                 2   176559
# 3                3             3               3                 3   176560
# 4                4             4               4                 4   176560
# 5                5             5               5                 5   176561
# ...            ...           ...             ...               ...      ...
# 186845      186845        186845          186845             11681   259353
# 186846      186846        186846          186846             11682   259354
# 186847      186847        186847          186847             11683   259355
# 186848      186848        186848          186848             11684   259356
# 186849      186849        186849          186849             11685   259357
#
# ...

# %%
dfk['month']=3
# Out:
# <ipython-input-8-d16931d2aa06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfk['month']=3

# %%
dfk
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1 Order ID  \
# 0                0             0               0                 0   176558
# 2                2             2               2                 2   176559
# 3                3             3               3                 3   176560
# 4                4             4               4                 4   176560
# 5                5             5               5                 5   176561
# ...            ...           ...             ...               ...      ...
# 186845      186845        186845          186845             11681   259353
# 186846      186846        186846          186846             11682   259354
# 186847      186847        186847          186847             11683   259355
# 186848      186848        186848          186848             11684   259356
# 186849      186849        186849          186849             11685   259357
#
# ...

# %%
dfk['month']=dfk['Order Date'].str[0:2]
# Out:
# <ipython-input-10-81565da49a53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfk['month']=dfk['Order Date'].str[0:2]

# %%
dfk
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1 Order ID  \
# 0                0             0               0                 0   176558
# 2                2             2               2                 2   176559
# 3                3             3               3                 3   176560
# 4                4             4               4                 4   176560
# 5                5             5               5                 5   176561
# ...            ...           ...             ...               ...      ...
# 186845      186845        186845          186845             11681   259353
# 186846      186846        186846          186846             11682   259354
# 186847      186847        186847          186847             11683   259355
# 186848      186848        186848          186848             11684   259356
# 186849      186849        186849          186849             11685   259357
#
# ...

# %%
dfr.head()
# Out:
# -----------------------------------------------
# NameError     Traceback (most recent call last)
# <ipython-input-12-56f5349bb93d> in <module>
# ----> 1 dfr.head()
#
# NameError: name 'dfr' is not defined

# %%
dfk.head()

# %%
dfk=dfk[dfk['month'].str[0:2]!="Or"]

# %%
dfk

# %%
dfk['month']=dfk['month'].astype('int32')

# %%
dfk['sales']=3

# %%
dfk

# %%
dkf['sales']=dfk['Quantity Ordered']*dfk['Price Each']

# %%
dfk['Quantity Ordered']=dfk['Quantity Ordered'].astype('float32')
dfk['Price Each']=dfk['Price Each'].astype('int32')
# Out:
# -----------------------------------------------
# ValueError    Traceback (most recent call last)
# <ipython-input-18-06e5f9b41a83> in <module>
# ----> 1 dfk['Quantity Ordered']=dfk['Quantity Ordered'].astype('float32')
#       2 dfk['Price Each']=dfk['Price Each'].astype('int32')
#
# c:\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5872         else:
#    5873             # else, only a single dtype is given
# -> 5874             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5875             return self._constructor(new_data).__finalize__(self, method="astype")
#    5876
#
# c:\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
# ...

# %%
dfk['sales']=dfk['Quantity Ordered']*dfk['Price Each']

# %%
dfk

# %%
g=dfk['sales']

# %%
mx=g.max()

# %%
mx

# %%
mon=dfk[dfk['month']]

# %%
dfk

# %%
g

# %%
dfk['month']

# %%
dfk.groupby('month').sum()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1
# month
# 01      701983866     701983866       701983866          47433245
# 02      736939638     736939638       736939638          72123197
# 03     1709538042    1709538042      1709538042         115333587
# 04      169872342     169872342       169872342         167977608
# 05     2130476341    2130476341      2130476341         137829259
# 06     1334894038    1334894038      1334894038          92330356
# 07     1207430793    1207430793      1207430793         102752005
# 08      292646206     292646206       292646206          71824951
# 09     2101562504    2101562504      2101562504          67863032
# 10     3346285693    3346285693      3346285693         206528743
# 11     2565279140    2565279140      2565279140         155210546
# 12     1076147574    1076147574      1076147574         313688708
# Or       32483429      32483429        32483429           2971917

# %%
dfk['month']=dfk.where(dfk['sales']>10000)
# Out:
# -----------------------------------------------
# KeyError      Traceback (most recent call last)
# c:\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError      Traceback (most recent call last)
# <ipython-input-20-46195e9ab551> in <module>
# ----> 1 dfk['month']=dfk.where(dfk['sales']>10000)
#
# ...
